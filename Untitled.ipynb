# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('averaged_perception_tagger')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jaiy9\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\jaiy9\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jaiy9\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Error loading averaged_perception_tagger: Package
# [nltk_data]     'averaged_perception_tagger' not found in index
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jaiy9\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jaiy9\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
text="I am learning NLP using Python"

words= word_tokenize(text)
print(words)
# Out:
# ['I', 'am', 'learning', 'NLP', 'using', 'Python']

# %%
from nltk.tokenize import sent_tokenize

text = "I am Dr Doom, Lets meet in Doomsday."
sentences = sent_tokenize(text)

print(sentences)
# Out:
# ['I am Dr Doom, Lets meet in Doomsday.']

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

text = "I am learning Python using NLTK"

words = word_tokenize(text)

stop_words = set(stopwords.words("english"))

filtered = []

for word in words:
    if word.lower() not in stop_words:
        filtered.append(word)

print(filtered)
# Out:
# ['learning', 'Python', 'using', 'NLTK']

# %%
from nltk.stem import PorterStemmer

stemmer=PorterStemmer()

words=[
    "playing",
    "played",
    "plays",
    "player"
]
for word in words:
    print(word,":",stemmer.stem(word))
# Out:
# playing : play
# played : play
# plays : play
# player : player
